# %% [markdown]
# # 1. Create a GitHub repository

# %%
from PIL import Image 
Image.open('images/github.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=573x591 at 0x15EE17B8B20>

# %% [markdown]
# - echo "# streamlit-to-heroku-tutorial" >> README.md
# - git init
# - git add README.md
# - git commit -m "first commit"
# - git branch -M master
# - git remote add origin https://github.com/RedaMastouri/DataDrivenAppUsingOptimalTransportAlgorithms.git
# - git push -u origin master

# %% [markdown]
# # 2. Create a requirements.txt, setup.sh, and Procfile

# %% [markdown]
# ### 2. a requirements.txt

# %% [markdown]
# This file is necessary for Heroku to know which libraries it needs to run your application.

# %%
''' Create a requirements.txt:'''
# pip install session-info
import session_info
session_info.show()

'''
pip freeze > requirements.txt
'''
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# PIL                 8.4.0
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# anyio                       NA
# attr                        21.2.0
# babel                       2.9.1
# backcall                    0.2.0
# brotli                      NA
# certifi                     2021.10.08
# cffi                        1.14.6
# chardet                     4.0.0
# charset_normalizer          2.0.6
# colorama                    0.4.4
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.4.1
# decorator                   5.1.0
# defusedxml                  0.7.1
# entrypoints                 0.3
# google                      NA
# idna                        3.2
# ipykernel                   6.4.1
# ipython_genutils            0.2.0
# jedi                        0.18.0
# ...

# %% [markdown]
# ### 2. b setup.sh

# %% [markdown]
# This is a shell file, and you need to add the following shell command inside the file.

# %%
'''
setup.sh
'''


'''

mkdir -p ~/.streamlit/echo "\
[server]\n\
headless = true\n\
port = $PORT\n\
enableCORS = false\n\
\n\
" > ~/.streamlit/config.toml

'''
# Out:
# '\n\nmkdir -p ~/.streamlit/echo "[server]\nheadless = true\nport = $PORT\nenableCORS = false\n\n" > ~/.streamlit/config.toml\n\n'

# %% [markdown]
# ### 2. c Procfile.

# %% [markdown]
# The “web” means that it’s a web app. The Procfile pretty much specifies the commands once you run the app on Heroku. We specify the shell file that we created above and then call Streamlit to run app.py.

# %%
'''
Procfile.
'''

# This is a shell file, and you need to add the following shell command inside the file.
# Out:
# '\nProcfile.\n'

# %% [markdown]
# # 3.  Connect to Heroku

# %%
Image.open('images/heroku.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=970x450 at 0x15EE1918F40>

# %%
Image.open('images/welcome_heroku.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=810x639 at 0x15EF1E53B20>

# %%
'''
Installing Heroku on local machine and create a free account
'''
#https://www.heroku.com/
'''
Heroku CLI
'''
# https://devcenter.heroku.com/articles/heroku-cli#download-and-install
Image.open('images/heroku_cli.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=584x373 at 0x15EE179F0A0>

# %% [markdown]
# log in to your Heroku account from the terminal. Run the following command in your terminal:

# %%
'''
heroku login

heroku create bunster_app
git push heroku master


git add -A
git commit -m "Type in a message"
git push 
'''
# Out:
# '\nheroku login\n\nheroku create bunster_app\ngit push heroku master\n\n\ngit add -A\ngit commit -m "Type in a message"\ngit push \n'
